# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pykrx import stock
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Dense, Flatten, Dropout, BatchNormalization, Reshape, LeakyReLU
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf
from datetime import datetime, timedelta

# %%
df = stock.get_market_ohlcv_by_date("20160701", "20210714", "000660")
cap_df = stock.get_market_cap_by_date("20160701", "20210714", "000660")
volume_df = stock.get_market_trading_volume_by_date("20160701", "20210714", "000660")
fm_df = stock.get_market_fundamental_by_date("20160701", "20210714", "000660")
short_df = stock.get_shorting_status_by_date("20160701", "20210714", "000660")
short_df = short_df.rename(columns={'거래량':'공매도거래량'})
short_df = short_df.rename(columns={'거래대금':'공매도거래대금'})
del cap_df['거래량']
del cap_df['상장주식수']
del volume_df['전체']
df = df.join(cap_df)
df = df.join(volume_df)
df = df.join(fm_df)
df = df.join(short_df)
print(df)
# Out:
#                 시가      고가      저가      종가      거래량            시가총액  \
# 날짜
# 2016-07-01   31800   32700   31600   32150  5289586  23405276034750
# 2016-07-04   32250   32900   32050   32750  3192033  23842077453750
# 2016-07-05   32650   32650   31850   31850  2577231  23186875325250
# 2016-07-06   31100   31350   30300   30600  6314347  22276872369000
# 2016-07-07   30750   31350   30600   30650  2715183  22313272487250
# ...            ...     ...     ...     ...      ...             ...
# 2021-07-08  123500  123500  121000  121500  3165552  88452287347500
# 2021-07-09  120500  120500  118000  119500  4823577  86996282617500
# 2021-07-12  121000  122000  119500  120000  2477201  87360283800000
# 2021-07-13  121000  123500  121000  123000  2879072  89544290895000
# 2021-07-14  122500  124000  121500  123500  2443087  89908292077500
#
#                     거래대금     기관합계   기타법인       개인  ...    BPS    PER   PBR  \
# 날짜                                                 ...
# 2016-07-01  170553435850  -214854  19678  -172061  ...  29377   5.36  1.09
# 2016-07-04  104097390400  -472909  -6429  -827181  ...  29377   5.46  1.11
# 2016-07-05   82885527300  -660935  66205   402555  ...  29377   5.31  1.08
# 2016-07-06  194010470200 -1450918  -3236  1722731  ...  29377   5.10  1.04
# 2016-07-07   83744992950    17481 -22584   108508  ...  29377   5.11  1.04
# ...                  ...      ...    ...      ...  ...    ...    ...   ...
# 2021-07-08  385948367500  -172724 -17929  1062210  ...  71275  17.48  1.70
# 2021-07-09  572864270909  -439187  16610  1576301  ...  71275  17.19  1.68
# 2021-07-12  298968546740   -65203  88975   174530  ...  71275  17.26  1.68
# 2021-07-13  353148544500   116372 -91839 -1093033  ...  71275  17.69  1.73
# 2021-07-14  300251945500  -106894 -21139  -393989  ...  71275  17.76  1.73
#
#              EPS   DIV   DPS  공매도거래량     잔고수량      공매도거래대금         잔고금액
# 날짜
# 2016-07-01  6002  1.56   500  261586  2213905   8443315950  71177045750
# 2016-07-04  6002  1.53   500  112669  2141972   3678679100  70149583000
# 2016-07-05  6002  1.57   500  115632  2202082   3712343200  70136311700
# 2016-07-06  6002  1.63   500  329900  2375264  10118639200  72683078400
# 2016-07-07  6002  1.63   500   66612  2361041   2052784750  72365906650
# ...          ...   ...   ...     ...      ...          ...          ...
# 2021-07-08  6952  0.96  1170  285446   587213  34825153000  71346379500
# 2021-07-09  6952  0.98  1170  383771   613094  45553465400  73264733000
# 2021-07-12  6952  0.98  1170   98987   591904  11952952000  71028480000
# 2021-07-13  6952  0.95  1170   62321   547308   7613267000  67318884000
# 2021-07-14  6952  0.95  1170   49033   552906   6017356000  68283891000
#
# [1239 rows x 21 columns]

# %%
df.to_csv('Sample.csv', encoding = "utf-8-sig")

# %%
test_array = np.zeros(shape = (21, 1239))
for i in range(21):
    tmp = []
    for j in range(len(df.index)):
        tmp.append(df.iloc[j][i])
    max_tmp = max(tmp)
    min_tmp = min(tmp)
    for j in range(len(tmp)):
        tmp[j] = (tmp[j] - min_tmp)/(max_tmp - min_tmp)
    arr_tmp = np.array(tmp)
    test_array[i] = arr_tmp
    #print(norm_arr.shape)

# %%
fin_array = test_array.T
fin_array = fin_array.reshape(-1, 21, 21, 1)
print(fin_array.shape)
# Out:
# (59, 21, 21, 1)

# %%
encoder_input = tf.keras.Input(shape=(21, 21, 1))

x = Conv2D(27, 3, padding='same')(encoder_input)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

x = Conv2D(81, 3, strides=3, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

x = Conv2D(81, 3, strides=7, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

x = Conv2D(81, 3, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

x = Flatten()(x)

encoder_output = Dense(2)(x)

encoder = Model(encoder_input, encoder_output)

# %%
decoder_input = tf.keras.Input(shape=(2, ))

x = Dense(1*1*81)(decoder_input)
x = Reshape((1, 1, 81))(x)

x = Conv2DTranspose(81, 3, strides=1, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(81, 3, strides=7, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(81, 3, strides=3, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(27, 3, strides=1, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

decoder_output = Conv2DTranspose(1, 3, strides=1, padding='same', activation='tanh')(x)

decoder = Model(decoder_input, decoder_output)

# %%
LEARNING_RATE = 0.0005
BATCH_SIZE = 32

encoder_in = tf.keras.Input(shape=(21, 21, 1))
x = encoder(encoder_in)
decoder_out = decoder(x)

auto_encoder = Model(encoder_in, decoder_out)
auto_encoder.compile(optimizer=tf.keras.optimizers.Adam(LEARNING_RATE), loss=tf.keras.losses.MeanSquaredError())

# %%
checkpoint_path = 'tmp/result.ckpt'
checkpoint = ModelCheckpoint(checkpoint_path, save_best_only=True, save_weights_only=True, monitor='loss', verbose=1)

auto_encoder.fit(fin_array, fin_array, batch_size=BATCH_SIZE, epochs=100, callbacks=[checkpoint], )
auto_encoder.load_weights(checkpoint_path)
# Out:
# Epoch 1/100
# 1/2 [==============>...............] - ETA: 0s - loss: 0.3308
# C:\Users\crara\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\ops\dataset_ops.py:3704: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable.debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# 2/2 [==============================] - 0s 109ms/step - loss: 0.2963
#
# Epoch 00001: loss improved from inf to 0.29631, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 2/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.2037
#
# Epoch 00002: loss improved from 0.29631 to 0.20368, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 3/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.1531
#
# Epoch 00003: loss improved from 0.20368 to 0.15313, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 4/100
# 2/2 [==============================] - 0s 108ms/step - loss: 0.1252
#
# Epoch 00004: loss improved from 0.15313 to 0.12523, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 5/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.1168
#
# Epoch 00005: loss improved from 0.12523 to 0.11684, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 6/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1052
#
# Epoch 00006: loss improved from 0.11684 to 0.10516, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 7/100
# 2/2 [==============================] - 0s 163ms/step - loss: 0.0956
#
# Epoch 00007: loss improved from 0.10516 to 0.09560, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 8/100
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0891
#
# Epoch 00008: loss improved from 0.09560 to 0.08915, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 9/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0915
#
# Epoch 00009: loss did not improve from 0.08915
# Epoch 10/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0812
#
# Epoch 00010: loss improved from 0.08915 to 0.08116, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 11/100
# 2/2 [==============================] - 0s 228ms/step - loss: 0.0776
#
# Epoch 00011: loss improved from 0.08116 to 0.07761, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 12/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0747
#
# Epoch 00012: loss improved from 0.07761 to 0.07473, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 13/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0730
#
# Epoch 00013: loss improved from 0.07473 to 0.07300, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 14/100
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0710
#
# Epoch 00014: loss improved from 0.07300 to 0.07104, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 15/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0697
#
# Epoch 00015: loss improved from 0.07104 to 0.06967, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 16/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0679
#
# Epoch 00016: loss improved from 0.06967 to 0.06792, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 17/100
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0667
#
# Epoch 00017: loss improved from 0.06792 to 0.06666, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 18/100
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0673
#
# Epoch 00018: loss did not improve from 0.06666
# Epoch 19/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0646
#
# Epoch 00019: loss improved from 0.06666 to 0.06462, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 20/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0644
#
# Epoch 00020: loss improved from 0.06462 to 0.06437, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 21/100
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0633
#
# Epoch 00021: loss improved from 0.06437 to 0.06334, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 22/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0617
#
# Epoch 00022: loss improved from 0.06334 to 0.06170, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 23/100
# 2/2 [==============================] - 0s 206ms/step - loss: 0.0617
#
# Epoch 00023: loss did not improve from 0.06170
# Epoch 24/100
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0614
#
# Epoch 00024: loss improved from 0.06170 to 0.06142, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 25/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0604
#
# Epoch 00025: loss improved from 0.06142 to 0.06041, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 26/100
# 2/2 [==============================] - 0s 148ms/step - loss: 0.0585
#
# Epoch 00026: loss improved from 0.06041 to 0.05852, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 27/100
# 2/2 [==============================] - 0s 138ms/step - loss: 0.0626
#
# Epoch 00027: loss did not improve from 0.05852
# Epoch 28/100
# 2/2 [==============================] - 0s 220ms/step - loss: 0.0570
#
# Epoch 00028: loss improved from 0.05852 to 0.05696, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 29/100
# 2/2 [==============================] - 0s 146ms/step - loss: 0.0572
#
# Epoch 00029: loss did not improve from 0.05696
# Epoch 30/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0560
#
# Epoch 00030: loss improved from 0.05696 to 0.05600, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 31/100
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0585
#
# Epoch 00031: loss did not improve from 0.05600
# Epoch 32/100
# 2/2 [==============================] - 0s 272ms/step - loss: 0.0560
#
# Epoch 00032: loss did not improve from 0.05600
# Epoch 33/100
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0549
#
# Epoch 00033: loss improved from 0.05600 to 0.05489, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 34/100
# 2/2 [==============================] - 1s 302ms/step - loss: 0.0555
#
# Epoch 00034: loss did not improve from 0.05489
# Epoch 35/100
# 2/2 [==============================] - 1s 260ms/step - loss: 0.0541
#
# Epoch 00035: loss improved from 0.05489 to 0.05408, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 36/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0548
#
# Epoch 00036: loss did not improve from 0.05408
# Epoch 37/100
# 2/2 [==============================] - 0s 177ms/step - loss: 0.0557
#
# Epoch 00037: loss did not improve from 0.05408
# Epoch 38/100
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0536
#
# Epoch 00038: loss improved from 0.05408 to 0.05360, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 39/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0533
#
# Epoch 00039: loss improved from 0.05360 to 0.05328, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 40/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0534
#
# Epoch 00040: loss did not improve from 0.05328
# Epoch 41/100
# 2/2 [==============================] - 0s 145ms/step - loss: 0.0553
#
# Epoch 00041: loss did not improve from 0.05328
# Epoch 42/100
# 2/2 [==============================] - 0s 248ms/step - loss: 0.0526
#
# Epoch 00042: loss improved from 0.05328 to 0.05257, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 43/100
# 2/2 [==============================] - 0s 200ms/step - loss: 0.0525
#
# Epoch 00043: loss improved from 0.05257 to 0.05254, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 44/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0549
#
# Epoch 00044: loss did not improve from 0.05254
# Epoch 45/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0523
#
# Epoch 00045: loss improved from 0.05254 to 0.05234, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 46/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0518
#
# Epoch 00046: loss improved from 0.05234 to 0.05178, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 47/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0523
#
# Epoch 00047: loss did not improve from 0.05178
# Epoch 48/100
# 2/2 [==============================] - 0s 257ms/step - loss: 0.0523
#
# Epoch 00048: loss did not improve from 0.05178
# Epoch 49/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0524
#
# Epoch 00049: loss did not improve from 0.05178
# Epoch 50/100
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0516
#
# Epoch 00050: loss improved from 0.05178 to 0.05161, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 51/100
# 2/2 [==============================] - 0s 148ms/step - loss: 0.0515
#
# Epoch 00051: loss improved from 0.05161 to 0.05146, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 52/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0510
#
# Epoch 00052: loss improved from 0.05146 to 0.05099, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 53/100
# 2/2 [==============================] - 0s 207ms/step - loss: 0.0511
#
# Epoch 00053: loss did not improve from 0.05099
# Epoch 54/100
# 2/2 [==============================] - 1s 230ms/step - loss: 0.0521
#
# Epoch 00054: loss did not improve from 0.05099
# Epoch 55/100
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0509
#
# Epoch 00055: loss improved from 0.05099 to 0.05095, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 56/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0512
#
# Epoch 00056: loss did not improve from 0.05095
# Epoch 57/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0521
#
# Epoch 00057: loss did not improve from 0.05095
# Epoch 58/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0523
#
# Epoch 00058: loss did not improve from 0.05095
# Epoch 59/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0530
#
# Epoch 00059: loss did not improve from 0.05095
# Epoch 60/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0515
#
# Epoch 00060: loss did not improve from 0.05095
# Epoch 61/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0506
#
# Epoch 00061: loss improved from 0.05095 to 0.05064, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 62/100
# 2/2 [==============================] - 0s 130ms/step - loss: 0.0506
#
# Epoch 00062: loss improved from 0.05064 to 0.05060, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 63/100
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0513
#
# Epoch 00063: loss did not improve from 0.05060
# Epoch 64/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0509
#
# Epoch 00064: loss did not improve from 0.05060
# Epoch 65/100
# 2/2 [==============================] - 0s 175ms/step - loss: 0.0512
#
# Epoch 00065: loss did not improve from 0.05060
# Epoch 66/100
# 2/2 [==============================] - 0s 206ms/step - loss: 0.0504
#
# Epoch 00066: loss improved from 0.05060 to 0.05036, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 67/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0506
#
# Epoch 00067: loss did not improve from 0.05036
# Epoch 68/100
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0511
#
# Epoch 00068: loss did not improve from 0.05036
# Epoch 69/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0512
#
# Epoch 00069: loss did not improve from 0.05036
# Epoch 70/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0511
#
# Epoch 00070: loss did not improve from 0.05036
# Epoch 71/100
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0552
#
# Epoch 00071: loss did not improve from 0.05036
# Epoch 72/100
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0515
#
# Epoch 00072: loss did not improve from 0.05036
# Epoch 73/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.0511
#
# Epoch 00073: loss did not improve from 0.05036
# Epoch 74/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0510
#
# Epoch 00074: loss did not improve from 0.05036
# Epoch 75/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0506
#
# Epoch 00075: loss did not improve from 0.05036
# Epoch 76/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0505
#
# Epoch 00076: loss did not improve from 0.05036
# Epoch 77/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0504
#
# Epoch 00077: loss did not improve from 0.05036
# Epoch 78/100
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0517
#
# Epoch 00078: loss did not improve from 0.05036
# Epoch 79/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0512
#
# Epoch 00079: loss did not improve from 0.05036
# Epoch 80/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0526
#
# Epoch 00080: loss did not improve from 0.05036
# Epoch 81/100
# 2/2 [==============================] - 0s 125ms/step - loss: 0.0505
#
# Epoch 00081: loss did not improve from 0.05036
# Epoch 82/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0502
#
# Epoch 00082: loss improved from 0.05036 to 0.05024, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 83/100
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0512
#
# Epoch 00083: loss did not improve from 0.05024
# Epoch 84/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0508
#
# Epoch 00084: loss did not improve from 0.05024
# Epoch 85/100
# 2/2 [==============================] - 0s 128ms/step - loss: 0.0501
#
# Epoch 00085: loss improved from 0.05024 to 0.05010, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 86/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0503
#
# Epoch 00086: loss did not improve from 0.05010
# Epoch 87/100
# 2/2 [==============================] - 0s 210ms/step - loss: 0.0506
#
# Epoch 00087: loss did not improve from 0.05010
# Epoch 88/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0504
#
# Epoch 00088: loss did not improve from 0.05010
# Epoch 89/100
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0502
#
# Epoch 00089: loss did not improve from 0.05010
# Epoch 90/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0503
#
# Epoch 00090: loss did not improve from 0.05010
# Epoch 91/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0511
#
# Epoch 00091: loss did not improve from 0.05010
# Epoch 92/100
# 2/2 [==============================] - 0s 142ms/step - loss: 0.0500
#
# Epoch 00092: loss improved from 0.05010 to 0.05000, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 93/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0512
#
# Epoch 00093: loss did not improve from 0.05000
# Epoch 94/100
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0512
#
# Epoch 00094: loss did not improve from 0.05000
# Epoch 95/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0512
#
# Epoch 00095: loss did not improve from 0.05000
# Epoch 96/100
# 2/2 [==============================] - 0s 218ms/step - loss: 0.0511
#
# Epoch 00096: loss did not improve from 0.05000
# Epoch 97/100
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0504
#
# Epoch 00097: loss did not improve from 0.05000
# Epoch 98/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0505
#
# Epoch 00098: loss did not improve from 0.05000
# Epoch 99/100
# 2/2 [==============================] - 0s 146ms/step - loss: 0.0500
#
# Epoch 00099: loss improved from 0.05000 to 0.04995, saving model to tmp\01-basic-auto-encoder.ckpt
# Epoch 100/100
# 2/2 [==============================] - 0s 179ms/step - loss: 0.0500
#
# Epoch 00100: loss did not improve from 0.04995

# %%
decoded_arr = auto_encoder.predict(fin_array)

# %%
a_array = fin_array.reshape(1239, 21)
b_array = decoded_arr.reshape(1239, 21)

# %%
f = open("flag_1.txt", 'w')
num = np.zeros(shape = (1239, 21))
flag_1 = 0
flag_2 = 0
flag_3 = 0
flag_4 = 0
flag_5 = 0
for i in range(1239):
    for j in range(21):
        num[i][j] = abs(a_array[i][j] - b_array[i][j])
        if (num[i][j] < 0.1):
            flag_1 += 1
            f.write("{} {}\n".format(i, j))
        elif (num[i][j] < 0.3):
            flag_2 += 1
        elif (num[i][j] < 0.5):
            flag_3 += 1
        elif (num[i][j] < 0.7):
            flag_4 += 1
        else:
            flag_5 += 1
#f.close()
print(flag_1, flag_2, flag_3, flag_4, flag_5)
# Out:
# 6452 14766 2972 1789 40

# %%
np.savetxt('AE_abs.csv', num, delimiter=',')
